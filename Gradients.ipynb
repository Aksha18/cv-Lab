# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img1 =cv2.imread('E:/sunflower.jpg')
img1= cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)

# %%
type(img1)
# Out:
# numpy.ndarray

# %%
plt.imshow(img1)

# %%
img2=cv2.imread('E:/flo.jpeg')
img2= cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img2)

# %%
img2.shape
# Out:
# (91, 551, 3)

# %%
plt.imshow(img2)

# %%
x_offset = 1200-600
y_offset = 837-600

# %%
roi = img1[x_offset:1200,y_offset:837]

# %%
plt.imshow(roi)

# %%
img2gray= cv2.cvtColor(img2,cv2.COLOR_RGB2GRAY)
plt.imshow(img2gray,cmap='gray')

# %%
mask_inv= cv2.bitwise_not(img2gray)

# %%
plt.imshow(mask_inv,cmap='gray')

# %%
fg=cv2.bitwise_or(img2,img2,mask= mask_inv)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-88-24390dc60590> in <module>
# ----> 1 fg=cv2.bitwise_or(img2,img2,mask= mask_inv)
#
# error: OpenCV(3.4.2) C:\Miniconda3\conda-bld\opencv-suite_1534379934306\work\modules\core\src\arithm.cpp:241: error: (-215:Assertion failed) (mtype == 0 || mtype == 1) && _mask.sameSize(*psrc1) in function 'cv::binary_op'

# %%
plt.imshow(fg)

# %%
final = cv2.bitwise_or(roi,fg)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-75-40378f1de558> in <module>
# ----> 1 final = cv2.bitwise_or(roi,fg)
#
# error: OpenCV(3.4.2) C:\Miniconda3\conda-bld\opencv-suite_1534379934306\work\modules\core\src\arithm.cpp:225: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and type), nor 'array op scalar', nor 'scalar op array' in function 'cv::binary_op'
